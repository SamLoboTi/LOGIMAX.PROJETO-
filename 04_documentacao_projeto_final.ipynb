# %% [markdown]
# # 04 - Documentação do Projeto Final
# Documentação oficial do pipeline ETL e auditoria.

# %% [markdown]
# ## 📌 Estrutura do Projeto
#
# ```
# /Projeto-Logistica/
# │
# ├── 01_tabelas_base.ipynb
# ├── 02_etl_pipeline.ipynb
# ├── 03_auditoria_inconsistencias.ipynb
# ├── 04_documentacao_projeto_final.ipynb
# │
# ├── input/
# │   ├── ERP_Pedidos.csv
# │   ├── WMS_Estoque.csv
# │   ├── TMS_Transporte.csv
# │
# ├── output/
#     ├── fato_pedidos.csv
#     ├── dim_cliente.csv
#     ├── dim_produto.csv
#     ├── dim_estoque.csv
#     └── dim_separacao.csv
# ```
#
# ## 📌 Objetivo
#
# O projeto simula um ambiente de logística com ERP, WMS e TMS para:
#
# - Criar tabelas base realistas
# - Unificar tudo via ETL
# - Calcular métricas logísticas
# - Criar uma auditoria automática de inconsistências
# - Gerar documentação clara de uso
#
# ## 📌 Tecnologias
#
# - Python
# - Pandas
# - Faker
# - Jupyter Notebooks
